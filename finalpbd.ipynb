# %%
import os 
folderPath=r"E:\wiki"
filePath=[os.path.join(folderPath,name) for name in os.listdir(folderPath) ]
files_array=[]
for path in filePath:
    with open(path,'r',encoding="ISO-8859-1" )as f:
        file=f.readlines()
        files_array.append(file)

# %%
files_array
# Out:
# [['[[Vriesea limonensis]]\n',
#   '\n',
#   'Vriesea limonensis is a species of plant in the Bromeliaceae family. It is endemic to Ecuador. Its natural habitat is subtropical or tropical moist montane forests. It is threatened by habitat loss. \n',
#   '\n',
#   '==Source==\n',
#   '* Manzanares, J.M. & Pitman, N. 2003. Vriesea limonensis. 2006 IUCN Red List of Threatened Species. Downloaded on 24 August 2007.\n',
#   '\n',
#   'limonensis\n',
#   '\n',
#   '\n',
#   '\n',
#   '[[Vriesea lutheri]]\n',
#   '\n',
#   'Vriesea lutheri is a species of plant in the Bromeliaceae family. It is endemic to Ecuador. Its natural habitat is subtropical or tropical moist montane forests. \n',
#   '\n',
#   '==Source==\n',
#   '* Manzanares, J.M. & Pitman, N. 2003. Vriesea lutheri. 2006 IUCN Red List of Threatened Species. Downloaded on 24 August 2007.\n',
#   '\n',
#   'limonensis\n',
#   '\n',
#   '\n',
#   '\n',
#   '[[Vriesea penduliscapa]]\n',
#   '\n',
# ...

# %%
lst2str=' '.join(map(str,files_array))
lst2str
# Out:
# '[\'[[Vriesea limonensis]]\\n\', \'\\n\', \'Vriesea limonensis is a species of plant in the Bromeliaceae family. It is endemic to Ecuador. Its natural habitat is subtropical or tropical moist montane forests. It is threatened by habitat loss. \\n\', \'\\n\', \'==Source==\\n\', \'* Manzanares, J.M. & Pitman, N. 2003. Vriesea limonensis. 2006 IUCN Red List of Threatened Species. Downloaded on 24 August 2007.\\n\', \'\\n\', \'limonensis\\n\', \'\\n\', \'\\n\', \'\\n\', \'[[Vriesea lutheri]]\\n\', \'\\n\', \'Vriesea lutheri is a species of plant in the Bromeliaceae family. It is endemic to Ecuador. Its natural habitat is subtropical or tropical moist montane forests. \\n\', \'\\n\', \'==Source==\\n\', \'* Manzanares, J.M. & Pitman, N. 2003. Vriesea lutheri. 2006 IUCN Red List of Threatened Species. Downloaded on 24 August 2007.\\n\', \'\\n\', \'limonensis\\n\', \'\\n\', \'\\n\', \'\\n\', \'[[Vriesea penduliscapa]]\\n\', \'\\n\', \'Vriesea penduliscapa is a species of plant in the Bromeli
# ...

# %%
#installing nltk
# %pip install nltk

# %%
#importing nltk
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
txt= word_tokenize(lst2str)

# %%
txt
# Out:
# ['[',
#  "'",
#  '[',
#  '[',
#  'Vriesea',
#  'limonensis',
#  ']',
#  ']',
#  '\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
#  "'Vriesea",
#  'limonensis',
#  'is',
#  'a',
#  'species',
#  'of',
#  'plant',
#  'in',
#  'the',
#  'Bromeliaceae',
#  'family',
#  '.',
#  'It',
#  'is',
#  'endemic',
#  'to',
#  'Ecuador',
#  '.',
#  'Its',
#  'natural',
#  'habitat',
#  'is',
#  'subtropical',
#  'or',
#  'tropical',
#  'moist',
#  'montane',
#  'forests',
#  '.',
#  'It',
#  'is',
#  'threatened',
#  'by',
#  'habitat',
#  'loss',
#  '.',
#  '\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
#  "'==Source==\\n",
#  "'",
#  ',',
#  "'",
#  '*',
#  'Manzanares',
#  ',',
#  'J.M',
#  '.',
#  '&',
#  'Pitman',
#  ',',
#  'N.',
#  '2003',
#  '.',
#  'Vriesea',
#  'limonensis',
#  '.',
#  '2006',
#  'IUCN',
#  'Red',
#  'List',
#  'of',
#  'Threatened',
#  'Species',
#  '.',
#  'Downloaded',
#  'on',
#  '24',
#  'August',
#  '2007.\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
# ...

# %%
data=[word for word in txt if not word in stopwords.words()]
print(data)
# Out:
# ['[', "'", '[', '[', 'Vriesea', 'limonensis', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'Vriesea", 'limonensis', 'species', 'plant', 'Bromeliaceae', 'family', '.', 'It', 'endemic', 'Ecuador', '.', 'Its', 'natural', 'habitat', 'subtropical', 'tropical', 'moist', 'montane', 'forests', '.', 'It', 'threatened', 'habitat', 'loss', '.', '\\n', "'", ',', "'\\n", "'", ',', "'==Source==\\n", "'", ',', "'", '*', 'Manzanares', ',', 'J.M', '.', '&', 'Pitman', ',', 'N.', '2003', '.', 'Vriesea', 'limonensis', '.', '2006', 'IUCN', 'Red', 'List', 'Threatened', 'Species', '.', 'Downloaded', '24', 'August', '2007.\\n', "'", ',', "'\\n", "'", ',', "'limonensis\\n", "'", ',', "'\\n", "'", ',', "'\\n", "'", ',', "'\\n", "'", ',', "'", '[', '[', 'Vriesea', 'lutheri', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'Vriesea", 'lutheri', 'species', 'plant', 'Bromeliaceae', 'family', '.', 'It', 'endemic', 'Ecuador', '.', 'Its', 'natural', 'habitat', 'subtropical', 'tropical', 'moist', 'montane', 'forests',
# ...

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
 nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\omw-1.4.zip.
# True

# %%
#lemmating data
from nltk.stem import WordNetLemmatizer
lemmmatizer=WordNetLemmatizer()
lem=[]
for x in data:
    lem.append(lemmmatizer.lemmatize(x))

#importing re library
import re
#updating data
updatedData=[re.sub('[^a-zA-Z0-9]+','',_) for _ in lem]
updatedData
# Out:
# ['',
#  '',
#  '',
#  '',
#  'Vriesea',
#  'limonensis',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'Vriesea',
#  'limonensis',
#  'specie',
#  'plant',
#  'Bromeliaceae',
#  'family',
#  '',
#  'It',
#  'endemic',
#  'Ecuador',
#  '',
#  'Its',
#  'natural',
#  'habitat',
#  'subtropical',
#  'tropical',
#  'moist',
#  'montane',
#  'forest',
#  '',
#  'It',
#  'threatened',
#  'habitat',
#  'loss',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'Sourcen',
#  '',
#  '',
#  '',
#  '',
#  'Manzanares',
#  '',
#  'JM',
#  '',
#  '',
#  'Pitman',
#  '',
#  'N',
#  '2003',
#  '',
#  'Vriesea',
#  'limonensis',
#  '',
#  '2006',
#  'IUCN',
#  'Red',
#  'List',
#  'Threatened',
#  'Species',
#  '',
#  'Downloaded',
#  '24',
#  'August',
#  '2007n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'limonensisn',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Vriesea',
#  'lutheri',
#  '',
#  '',
#  'n',
#  '',
#  '',
# ...

# %%
# now forming clusters of the list lem[]
# !pip install scikit-learn

# %%
import sklearn
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.cluster import KMeans
from warnings import simplefilter 

simplefilter(action='ignore' , category=FutureWarning)
vectorizer= TfidfVectorizer(stop_words='english')
x=vectorizer.fit_transform(updatedData)

k=6
model=KMeans(n_clusters=k,init='k-means++' ,max_iter=100 ,n_init=1)
model.fit(x)

print("Top per cluster ")
order_centroids=model.cluster_centers_.argsort()[:, ::-1] 
terms =vectorizer.get_feature_names()
for i in range(k):
    print("Cluster %d :" % i), 
    for ind in order_centroids[i, :10]:
        print('%s' % terms[ind])
# Out:
# Top per cluster
# Cluster 0 :
# new
# york
# county
# 2006
# wallenia
# 1954
# mdash
# 1998
# 2004
# plant
# Cluster 1 :
# 1997
# zoology
# curtin
# development
# desmond
# denoted
# denizlispor
# delaware
# deceased
# debut
# Cluster 2 :
# 2001
# zoology
# curtin
# development
# desmond
# denoted
# denizlispor
# delaware
# deceased
# debut
# Cluster 3 :
# fellow
# zoology
# curtin
# desmond
# denoted
# denizlispor
# delaware
# deceased
# debut
# dead
# Cluster 4 :
# trove
# curtin
# development
# desmond
# denoted
# denizlispor
# delaware
# deceased
# debut
# dead
# Cluster 5 :
# family
# zoology
# device
# desmond
# denoted
# denizlispor
# delaware
# deceased
# debut
# dead

# %%
print('clustters are: \n')


Y = vectorizer.transform(["family"]) 
guessing = model.predict(Y) 
print(guessing)
# Out:
# clustters are:
#
# [5]
